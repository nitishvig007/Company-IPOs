# %% [markdown]
# # About Dataset
#
# ## Company IPO : 2019 - 2021
#
# An initial public offering (IPO) refers to the process of offering shares of a private corporation to the public in a new stock issuance. An IPO allows a company to raise capital from public investors. The transition from a private to a public company can be an important time for private investors to fully realize gains from their investment as it typically includes a share premium for current private investors. Meanwhile, it also allows public investors to participate in the offering.
# Global initial public offering (IPO) issuances and proceeds set a new record in 2021, rising 64% and 67% respectively compared with 2020 The fourth quarter of the year was particularly active, with deal numbers reaching their highest since the same period in 2007 However, growth in IPO activity in Asia Pacific was relatively weak
#
#
# ### Source
# https://stockanalysis.com/

# %%
#Linear Algrebra
import numpy as np  
#Data Preprocessing 
import pandas as pd 
#For Data Viz. 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('company_ipo.csv')
df.head()
# Out:
#    ID      IPO Date Symbol                    Company Name IPO Price Current  \
# 0   1  Dec 21, 2021   NVAC           NorthView Acquisition    $10.00  $10.03
# 1   2  Dec 21, 2021   LSPR     Larkspur Health Acquisition    $10.00   $9.98
# 2   3  Dec 21, 2021   SAGA            Sagaliam Acquisition    $10.00   $9.97
# 3   4  Dec 17, 2021   RCAC  Revelstone Capital Acquisition    $10.00   $9.90
# 4   5  Dec 17, 2021   APCA                  AP Acquisition    $10.00  $10.11
#
#    Return
# 0   0.30%
# 1  -0.20%
# 2  -0.30%
# 3  -1.00%
# 4   1.10%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1765 entries, 0 to 1764
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1765 non-null   int64
#  1   IPO Date      1765 non-null   object
#  2   Symbol        1765 non-null   object
#  3   Company Name  1765 non-null   object
#  4   IPO Price     1765 non-null   object
#  5   Current       1765 non-null   object
#  6   Return        1765 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 96.6+ KB

# %% [markdown]
# **Key takeaways**
#
# 1. The dataset has shape of 1765 X 7.
# 2. ID is int type data and IPO Date,Symbol,Company Name,IPO Price,Current,Return are categorical data.
# 3. The dataset has no null values ,
# 4. The dataset has no missing values.

# %%
df["IPO Date"] = pd.to_datetime(df["IPO Date"])

df['Year'] = df["IPO Date"].dt.year

# %%
df.head()
# Out:
#    ID   IPO Date Symbol                    Company Name IPO Price Current  \
# 0   1 2021-12-21   NVAC           NorthView Acquisition    $10.00  $10.03
# 1   2 2021-12-21   LSPR     Larkspur Health Acquisition    $10.00   $9.98
# 2   3 2021-12-21   SAGA            Sagaliam Acquisition    $10.00   $9.97
# 3   4 2021-12-17   RCAC  Revelstone Capital Acquisition    $10.00   $9.90
# 4   5 2021-12-17   APCA                  AP Acquisition    $10.00  $10.11
#
#    Return  Year
# 0   0.30%  2021
# 1  -0.20%  2021
# 2  -0.30%  2021
# 3  -1.00%  2021
# 4   1.10%  2021

# %%
df.Year.value_counts()
# Out:
# 2021    1053
# 2020     480
# 2019     232
# Name: Year, dtype: int64

# %% [markdown]
# **Key takeaways**
#
# 1. 1053 IPOs in 2021
# 2. 480 IPOs in 2020
# 3. 232 IPOs in 2019

# %% [markdown]
# **To perform furthur analysis, we are dropping "$" from IPO and Current Price, and dropping "%" from Return**

# %%
df['Current'] = df['Current'].apply(lambda x : x.split("$")[1]).astype(float)

# %%
df['IPO Price'] = df['IPO Price'].apply(lambda x : x.split("$")[1]).astype(float)

# %%
df['Return'] = df['Return'].apply(lambda x : x.split("%")[0]).astype(float)

# %%
df.head()
# Out:
#    ID   IPO Date Symbol                    Company Name  IPO Price  Current  \
# 0   1 2021-12-21   NVAC           NorthView Acquisition       10.0    10.03
# 1   2 2021-12-21   LSPR     Larkspur Health Acquisition       10.0     9.98
# 2   3 2021-12-21   SAGA            Sagaliam Acquisition       10.0     9.97
# 3   4 2021-12-17   RCAC  Revelstone Capital Acquisition       10.0     9.90
# 4   5 2021-12-17   APCA                  AP Acquisition       10.0    10.11
#
#    Return  Year
# 0     0.3  2021
# 1    -0.2  2021
# 2    -0.3  2021
# 3    -1.0  2021
# 4     1.1  2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1765 entries, 0 to 1764
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            1765 non-null   int64
#  1   IPO Date      1765 non-null   datetime64[ns]
#  2   Symbol        1765 non-null   object
#  3   Company Name  1765 non-null   object
#  4   IPO Price     1765 non-null   float64
#  5   Current       1765 non-null   float64
#  6   Return        1765 non-null   float64
#  7   Year          1765 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 110.4+ KB

# %%
plt.figure(figsize = (10, 10))


sns.heatmap(df[["Current", "IPO Price", "Return"]].corr(), annot = True, cmap="Purples"   )

# %%
df.head()
# Out:
#    ID   IPO Date Symbol                    Company Name  IPO Price  Current  \
# 0   1 2021-12-21   NVAC           NorthView Acquisition       10.0    10.03
# 1   2 2021-12-21   LSPR     Larkspur Health Acquisition       10.0     9.98
# 2   3 2021-12-21   SAGA            Sagaliam Acquisition       10.0     9.97
# 3   4 2021-12-17   RCAC  Revelstone Capital Acquisition       10.0     9.90
# 4   5 2021-12-17   APCA                  AP Acquisition       10.0    10.11
#
#    Return  Year
# 0     0.3  2021
# 1    -0.2  2021
# 2    -0.3  2021
# 3    -1.0  2021
# 4     1.1  2021

# %%
print("Dataframe Shape : ", df.shape)
print("Dataframe Symbol Shape : ", df['Symbol'].shape)
# Out:
# Dataframe Shape :  (1765, 7)
# Dataframe Symbol Shape :  (1765,)

# %% [markdown]
# **Setting the ID as Index**

# %%
df.set_index("ID", inplace = True)

# %%
df['Symbol'].value_counts().head(10)
# Out:
# HYAC    2
# PANA    2
# CPAA    2
# KCAC    2
# INAQ    2
# LCA     2
# NHIC    2
# PRSR    1
# BJDX    1
# DERM    1
# Name: Symbol, dtype: int64

# %% [markdown]
# **Key takeaways**
#
# Since there are Symbols occuring twice, that certainly means that there are listed companies with single parent company name.
#
# let's study them seperately

# %%
df[df["Symbol"] == "KCAC"]
# Out:
#        IPO Date Symbol                       Company Name  IPO Price  Current  \
# ID
# 806  2021-02-26   KCAC  Kensington Capital Acquisition II       10.0     8.07
# 1442 2020-06-26   KCAC     Kensington Capital Acquisition       10.0    23.50
#
#       Return  Year
# ID
# 806    -19.3  2021
# 1442   135.0  2020

# %%
df[df["Symbol"] == "INAQ"]
# Out:
#        IPO Date Symbol         Company Name  IPO Price  Current  Return  Year
# ID
# 324  2021-09-02   INAQ  Insight Acquisition       10.0     9.78   -2.16  2021
# 1334 2020-09-03   INAQ  INSU Acquisition II       10.0    18.00   80.00  2020

# %%
df[df["Symbol"] == "NHIC"]
# Out:
#        IPO Date Symbol           Company Name  IPO Price  Current  Return  \
# ID
# 199  2021-10-21   NHIC  NewHold Investment II       10.0     9.99    -0.1
# 1385 2020-07-31   NHIC     NewHold Investment       10.0     9.55    -4.5
#
#       Year
# ID
# 199   2021
# 1385  2020

# %%
df[df["Symbol"] == "CPAA"]
# Out:
#        IPO Date Symbol                  Company Name  IPO Price  Current  \
# ID
# 356  2021-08-10   CPAA  Conyers Park III Acquisition       10.0     9.72
# 1640 2019-07-18   CPAA   Conyers Park II Acquisition       10.0     8.86
#
#       Return  Year
# ID
# 356     -2.8  2021
# 1640   -11.4  2019

# %%
df[df["Symbol"] == "HYAC"]
# Out:
#        IPO Date Symbol              Company Name  IPO Price  Current  Return  \
# ID
# 789  2021-03-02   HYAC  Haymaker Acquisition III       10.0     9.81    -1.9
# 1672 2019-06-07   HYAC   Haymaker Acquisition II       10.0     9.52    -4.8
#
#       Year
# ID
# 789   2021
# 1672  2019

# %%
df[df["Symbol"] == "LCA"]
# Out:
#        IPO Date Symbol           Company Name  IPO Price  Current  Return  \
# ID
# 662  2021-03-25    LCA  Landcadia Holdings IV       10.0     9.74   -2.58
# 1695 2019-05-07    LCA  Landcadia Holdings II       10.0    25.49  154.90
#
#       Year
# ID
# 662   2021
# 1695  2019

# %%
df[df["Symbol"] == "PANA"]
# Out:
#        IPO Date Symbol            Company Name  IPO Price  Current  Return  \
# ID
# 643  2021-04-07   PANA  Panacea Acquisition II       10.0     9.76    -2.4
# 1433 2020-07-01   PANA     Panacea Acquisition       10.0    10.42     4.2
#
#       Year
# ID
# 643   2021
# 1433  2020

# %% [markdown]
# **Key takeaways**
#
# Out of all the listed companies that are occuring twice, we have noticed that all of them has IPO Price as $10, but they have grown and shrinked due time.
#
# There are companies that have shown drastically amazing changes in Return despite same IPO price under same listed company.
# Those are :
#
# - LCA 	Landcadia Holdings II
# - INAQ 	INSU Acquisition II
# - KCAC 	Kensington Capital Acquisition

# %% [markdown]
# **Finding the records that are having maximum or minimum Current, IPO Price and Returns**

# %%
df[  df['IPO Price'] == df['IPO Price'].max()  ]
# Out:
#       IPO Date Symbol     Company Name  IPO Price  Current  Return  Year
# ID
# 631 2021-04-14   COIN  Coinbase Global      250.0   247.69   -0.92  2021

# %%
df[  df['IPO Price'] == df['IPO Price'].min()  ]
# Out:
#        IPO Date Symbol                                       Company Name  \
# ID
# 90   2021-11-15    ONL                                  Orion Office REIT
# 122  2021-11-09    PRM                                Perimeter Solutions
# 124  2021-11-08   LYLT                                   Loyalty Ventures
# 129  2021-11-05   TSVT                                       2seventy bio
# 144  2021-11-04     KD                                   Kyndryl Holdings
# 195  2021-10-22    GET  Getnet Adquirencia E Servicos Para Meios De Pa...
# 222  2021-10-18     OZ                                Belpointe PREP, LLC
# 238  2021-10-13   CLST                                   Catalyst Bancorp
# 246  2021-10-08   CCSI                          Consensus Cloud Solutions
# 258  2021-10-05   CION                                    CĪON Investment
# 267  2021-10-01   SLVM                                            Sylvamo
# 316  2021-09-13   SGML                                      Sigma Lithium
# ...

# %%
df[  df['Current'] == df['Current'].max()  ]
# Out:
#        IPO Date Symbol Company Name  IPO Price  Current  Return  Year
# ID
# 1313 2020-09-16   SNOW    Snowflake      120.0   354.82  195.68  2020

# %%
df[  df['Current'] == df['Current'].min()  ]
# Out:
#        IPO Date Symbol           Company Name  IPO Price  Current  Return  \
# ID
# 999  2021-01-15    TBA  Thoma Bravo Advantage       10.0      0.0     0.0
# 1608 2019-09-11   SONG                 Akazoo        0.0      0.0     0.0
#
#       Year
# ID
# 999   2021
# 1608  2019

# %%
df[  df['Return'] == df['Return'].max()  ]
# Out:
#        IPO Date Symbol Company Name  IPO Price  Current   Return  Year
# ID
# 1552 2019-11-21   SITM       SiTime       13.0   272.84  1998.77  2019

# %%
df[  df['Return'] == df['Return'].min()  ]
# Out:
#        IPO Date Symbol             Company Name  IPO Price  Current  Return  \
# ID
# 1567 2019-11-05     QK  Q&K International Group       17.0     0.42   -97.5
#
#       Year
# ID
# 1567  2019

# %% [markdown]
# **Finding the records that are having maximum or minimum Current, IPO Price and Returns with respect to each year**

# %%
years = df['Year'].value_counts().index
years

data_ = ["Return", 'Current', "IPO Price"]

# %%
# Print the company names of all the years that are giving highest returns

for y in years : 
    df1 = df[df['Year'] == y]
    print()
    print("**" * 30)
    print(f"In Year {y}")
    for d in data_ : 
        res1 = df1[df1[d] == df1[d].max()]['Company Name'].values
        res2 = df1[df1[d] == df1[d].min()]['Company Name'].values
        
        print(f"Company with the highest {d} : {res1}")
        print(f"Company with the least {d} : {res2}")
        
        print("--" * 20)
# Out:
# ************************************************************
# In Year 2021
# Company with the highest Return : ['Digital World Acquisition']
# Company with the least Return : ['Zhangmen Education']
# ----------------------------------------
# Company with the highest Current : ['monday.com']
# Company with the least Current : ['Thoma Bravo Advantage']
# ----------------------------------------
# Company with the highest IPO Price : ['Coinbase Global']
# Company with the least IPO Price : ['Orion Office REIT' 'Perimeter Solutions' 'Loyalty Ventures'
#  '2seventy bio' 'Kyndryl Holdings'
#  'Getnet Adquirencia E Servicos Para Meios De Pagamento'
#  'Belpointe PREP, LLC' 'Catalyst Bancorp' 'Consensus Cloud Solutions'
#  'CĪON Investment' 'Sylvamo' 'Sigma Lithium' 'IceCure Medical'
#  "Victoria's Secret & Co." 'ABVC BioPharma'
#  'Thornburg Income Builder Opportunities Trust' 'U.S. Century Bank'
#  'TC Bancshares' 'Blue Foundry Bancorp' 'PB Bankshares'
# ...
